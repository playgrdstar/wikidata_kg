# %%
import os
import time

import pandas as pd
from tqdm import tqdm
from pathlib import Path
from qwikidata.linked_data_interface import get_entity_dict_from_api
from qwikidata.entity import WikidataItem, WikidataProperty, WikidataLexeme

# %%
nasdaq_tickers = pd.read_csv('NASDAQ_wiki.csv', names=['ticker', 'wikidataid'])
nyse_tickers = pd.read_csv('NYSE_wiki.csv', names=['ticker', 'wikidataid'])
nasdaq_tickers['mkt'] = 'NASDAQ'
nyse_tickers['mkt'] = 'NYSE'
tickers = pd.concat([nyse_tickers, nasdaq_tickers], axis=0)
assert len(tickers) == len(nasdaq_tickers) + len(nyse_tickers)

# %%
tickers = tickers[tickers.wikidataid != 'unknown']

# %%
company_triplets = []
tickers_list = list(tickers.wikidataid.values)
failed_tickers = []
print(f'Total number of tickers: {len(tickers_list)}')
# for i in tqdm(range(len(tickers))):
while len(tickers_list) > 0:
    # sel_ticker = tickers.wikidataid.values[0]
    sel_ticker = tickers_list.pop()
    print(f'Trying to retrieve: {sel_ticker}')
    try:
        company = get_entity_dict_from_api(sel_ticker)
        print(f'Succeeded in retrieving: {sel_ticker} | Number of tickers left: {len(tickers_list)}')
    except:
        time.sleep(5)
        print(f'Failed in retrieving: {sel_ticker} | Number of tickers left: {len(tickers_list)}')
        print('Retrying')
        try:
            company = get_entity_dict_from_api(sel_ticker)  
            print(f'Succeeded in retrieving: {sel_ticker} | Number of tickers left: {len(tickers_list)}')
        except:
            failed_tickers.append(sel_ticker)
            continue

    try:
        for claim in company['claims'].keys():
            for claimno in range(len(company['claims'][claim])):
                if company['claims'][claim][claimno]['mainsnak']['datatype'] == 'wikibase-item':
                    # print(f"{claim} | Q{company['claims'][claim][claimno]['mainsnak']['datavalue']['value']['numeric-id']}")
                    company_triplets.append({'source': company['id'], 'source_name': company['labels']['en']['value'], 'relationship': claim, 
                                            'target': 'Q' + str(company['claims'][claim][claimno]['mainsnak']['datavalue']['value']['numeric-id']),
                                            'ticker': tickers[tickers.wikidataid == company['id']].ticker.values[0], 
                                            'id': tickers[tickers.wikidataid == company['id']].wikidataid.values[0], 
                                            'mkt': tickers[tickers.wikidataid == company['id']].mkt.values[0]})
    except:
        # redirects can happen to map old ID to new ID so using sel_ticker
        # can check later if company['id] != sel_ticker
        company_triplets.append({'source': company['id'], 'source_name': 'NIL', 'relationship': 'NIL', 'target': 'NIL',
                                            'ticker': tickers[tickers.wikidataid == sel_ticker].ticker.values[0], 
                                            'id': tickers[tickers.wikidataid == sel_ticker].wikidataid.values[0], 
                                            'mkt': tickers[tickers.wikidataid == sel_ticker].mkt.values[0]})

    # break
# Out:
# Total number of tickers: 1109
# Trying to retrieve: Q8075252
# Succeeded in retrieving: Q8075252 | Number of tickers left: 1108
# Trying to retrieve: Q8072579
# Succeeded in retrieving: Q8072579 | Number of tickers left: 1107
# Trying to retrieve: Q7089136
# Succeeded in retrieving: Q7089136 | Number of tickers left: 1106
# Trying to retrieve: Q2443609
# Succeeded in retrieving: Q2443609 | Number of tickers left: 1105
# Trying to retrieve: Q8046104
# Succeeded in retrieving: Q8046104 | Number of tickers left: 1104
# Trying to retrieve: Q8046013
# Succeeded in retrieving: Q8046013 | Number of tickers left: 1103
# Trying to retrieve: Q5281
# Succeeded in retrieving: Q5281 | Number of tickers left: 1102
# Trying to retrieve: Q834888
# Succeeded in retrieving: Q834888 | Number of tickers left: 1101
# Trying to retrieve: Q1046482
# Succeeded in retrieving: Q1046482 | Number of tickers left: 1100
# Trying to retrieve: Q2274089
# Succeeded in retrieving: Q2274089 | Number of tickers left: 1099
# Trying to retrieve: Q8033550
# Succeeded in retrieving: Q8033550 | Number of tickers left: 1098
# Trying to retrieve: Q6545346
# Succeeded in retrieving: Q6545346 | Number of tickers left: 1097
# Trying to retrieve: Q7983629
# Succeeded in retrieving: Q7983629 | Number of tickers left: 1096
# Trying to retrieve: Q4938392
# Succeeded in retrieving: Q4938392 | Number of tickers left: 1095
# Trying to retrieve: Q8027406
# Succeeded in retrieving: Q8027406 | Number of tickers left: 1094
# Trying to retrieve: Q7983382
# Succeeded in retrieving: Q7983382 | Number of tickers left: 1093
# Trying to retrieve: Q738770
# Succeeded in retrieving: Q738770 | Number of tickers left: 1092
# Trying to retrieve: Q7971859
# Succeeded in retrieving: Q7971859 | Number of tickers left: 1091
# Trying to retrieve: Q7987101
# Succeeded in retrieving: Q7987101 | Number of tickers left: 1090
# Trying to retrieve: Q7907548
# Succeeded in retrieving: Q7907548 | Number of tickers left: 1089
# Trying to retrieve: Q7924358
# Succeeded in retrieving: Q7924358 | Number of tickers left: 1088
# Trying to retrieve: Q2744099
# Succeeded in retrieving: Q2744099 | Number of tickers left: 1087
# Trying to retrieve: Q2516971
# Succeeded in retrieving: Q2516971 | Number of tickers left: 1086
# Trying to retrieve: Q7756963
# Succeeded in retrieving: Q7756963 | Number of tickers left: 1085
# Trying to retrieve: Q734338
# Succeeded in retrieving: Q734338 | Number of tickers left: 1084
# Trying to retrieve: Q7921370
# Succeeded in retrieving: Q7921370 | Number of tickers left: 1083
# Trying to retrieve: Q7921363
# Succeeded in retrieving: Q7921363 | Number of tickers left: 1082
# Trying to retrieve: Q7920749
# Succeeded in retrieving: Q7920749 | Number of tickers left: 1081
# Trying to retrieve: Q122141
# Succeeded in retrieving: Q122141 | Number of tickers left: 1080
# Trying to retrieve: Q7501097
# Succeeded in retrieving: Q7501097 | Number of tickers left: 1079
# Trying to retrieve: Q17113726
# Succeeded in retrieving: Q17113726 | Number of tickers left: 1078
# Trying to retrieve: Q214346
# Succeeded in retrieving: Q214346 | Number of tickers left: 1077
# Trying to retrieve: Q1665653
# Succeeded in retrieving: Q1665653 | Number of tickers left: 1076
# Trying to retrieve: Q3552193
# Succeeded in retrieving: Q3552193 | Number of tickers left: 1075
# Trying to retrieve: Q7888979
# Succeeded in retrieving: Q7888979 | Number of tickers left: 1074
# Trying to retrieve: Q7881772
# Succeeded in retrieving: Q7881772 | Number of tickers left: 1073
# Trying to retrieve: Q7865088
# Succeeded in retrieving: Q7865088 | Number of tickers left: 1072
# Trying to retrieve: Q7880250
# Succeeded in retrieving: Q7880250 | Number of tickers left: 1071
# Trying to retrieve: Q7880076
# Succeeded in retrieving: Q7880076 | Number of tickers left: 1070
# Trying to retrieve: Q17145997
# Succeeded in retrieving: Q17145997 | Number of tickers left: 1069
# Trying to retrieve: Q7887635
# Succeeded in retrieving: Q7887635 | Number of tickers left: 1068
# Trying to retrieve: Q16920636
# Succeeded in retrieving: Q16920636 | Number of tickers left: 1067
# Trying to retrieve: Q7876533
# Succeeded in retrieving: Q7876533 | Number of tickers left: 1066
# Trying to retrieve: Q16959074
# Succeeded in retrieving: Q16959074 | Number of tickers left: 1065
# Trying to retrieve: Q1583606
# Succeeded in retrieving: Q1583606 | Number of tickers left: 1064
# Trying to retrieve: Q7707945
# Succeeded in retrieving: Q7707945 | Number of tickers left: 1063
# Trying to retrieve: Q193412
# Succeeded in retrieving: Q193412 | Number of tickers left: 1062
# Trying to retrieve: Q7858146
# Succeeded in retrieving: Q7858146 | Number of tickers left: 1061
# Trying to retrieve: Q94933
# Succeeded in retrieving: Q94933 | Number of tickers left: 1060
# Trying to retrieve: Q7706196
# Succeeded in retrieving: Q7706196 | Number of tickers left: 1059
# Trying to retrieve: Q7695737
# Succeeded in retrieving: Q7695737 | Number of tickers left: 1058
# Trying to retrieve: Q7555824
# Succeeded in retrieving: Q7555824 | Number of tickers left: 1057
# Trying to retrieve: Q15109925
# Succeeded in retrieving: Q15109925 | Number of tickers left: 1056
# Trying to retrieve: Q7848087
# Succeeded in retrieving: Q7848087 | Number of tickers left: 1055
# Trying to retrieve: Q3511946
# Succeeded in retrieving: Q3511946 | Number of tickers left: 1054
# Trying to retrieve: Q17079979
# Succeeded in retrieving: Q17079979 | Number of tickers left: 1053
# Trying to retrieve: Q1770710
# Succeeded in retrieving: Q1770710 | Number of tickers left: 1052
# Trying to retrieve: Q6522339
# Succeeded in retrieving: Q6522339 | Number of tickers left: 1051
# Trying to retrieve: Q7799971
# Succeeded in retrieving: Q7799971 | Number of tickers left: 1050
# Trying to retrieve: Q7809764
# Succeeded in retrieving: Q7809764 | Number of tickers left: 1049
# Trying to retrieve: Q5453008
# Succeeded in retrieving: Q5453008 | Number of tickers left: 1048
# Trying to retrieve: Q19873469
# Succeeded in retrieving: Q19873469 | Number of tickers left: 1047
# Trying to retrieve: Q1715931
# Succeeded in retrieving: Q1715931 | Number of tickers left: 1046
# Trying to retrieve: Q2087612
# Succeeded in retrieving: Q2087612 | Number of tickers left: 1045
# Trying to retrieve: Q6541978
# Succeeded in retrieving: Q6541978 | Number of tickers left: 1044
# Trying to retrieve: Q7662679
# Succeeded in retrieving: Q7662679 | Number of tickers left: 1043
# Trying to retrieve: Q1571490
# Succeeded in retrieving: Q1571490 | Number of tickers left: 1042
# Trying to retrieve: Q7131487
# Succeeded in retrieving: Q7131487 | Number of tickers left: 1041
# Trying to retrieve: Q2373884
# Succeeded in retrieving: Q2373884 | Number of tickers left: 1040
# Trying to retrieve: Q7538146
# Succeeded in retrieving: Q7538146 | Number of tickers left: 1039
# Trying to retrieve: Q13529476
# Succeeded in retrieving: Q13529476 | Number of tickers left: 1038
# Trying to retrieve: Q705392
# Succeeded in retrieving: Q705392 | Number of tickers left: 1037
# Trying to retrieve: Q7597506
# Succeeded in retrieving: Q7597506 | Number of tickers left: 1036
# Trying to retrieve: Q7605667
# Succeeded in retrieving: Q7605667 | Number of tickers left: 1035
# Trying to retrieve: Q14705393
# Succeeded in retrieving: Q14705393 | Number of tickers left: 1034
# Trying to retrieve: Q7392916
# Succeeded in retrieving: Q7392916 | Number of tickers left: 1033
# Trying to retrieve: Q3973262
# Succeeded in retrieving: Q3973262 | Number of tickers left: 1032
# Trying to retrieve: Q645525
# Succeeded in retrieving: Q645525 | Number of tickers left: 1031
# Trying to retrieve: Q7573912
# Succeeded in retrieving: Q7573912 | Number of tickers left: 1030
# Trying to retrieve: Q7598289
# Succeeded in retrieving: Q7598289 | Number of tickers left: 1029
# Trying to retrieve: Q2443320
# Succeeded in retrieving: Q2443320 | Number of tickers left: 1028
# Trying to retrieve: Q7561808
# Succeeded in retrieving: Q7561808 | Number of tickers left: 1027
# Trying to retrieve: Q965133
# Succeeded in retrieving: Q965133 | Number of tickers left: 1026
# Trying to retrieve: Q683006
# Succeeded in retrieving: Q683006 | Number of tickers left: 1025
# Trying to retrieve: Q2303478
# Succeeded in retrieving: Q2303478 | Number of tickers left: 1024
# Trying to retrieve: Q7638414
# Succeeded in retrieving: Q7638414 | Number of tickers left: 1023
# Trying to retrieve: Q3459777
# Succeeded in retrieving: Q3459777 | Number of tickers left: 1022
# Trying to retrieve: Q1817174
# Succeeded in retrieving: Q1817174 | Number of tickers left: 1021
# Trying to retrieve: Q2286044
# Succeeded in retrieving: Q2286044 | Number of tickers left: 1020
# Trying to retrieve: Q7537214
# Succeeded in retrieving: Q7537214 | Number of tickers left: 1019
# Trying to retrieve: Q17112054
# Succeeded in retrieving: Q17112054 | Number of tickers left: 1018
# Trying to retrieve: Q938668
# Succeeded in retrieving: Q938668 | Number of tickers left: 1017
# Trying to retrieve: Q7447744
# Failed in retrieving: Q7447744 | Number of tickers left: 1016
# Retrying
# Trying to retrieve: Q905049
# Succeeded in retrieving: Q905049 | Number of tickers left: 1015
# Trying to retrieve: Q17155112
# Succeeded in retrieving: Q17155112 | Number of tickers left: 1014
# Trying to retrieve: Q7505672
# Succeeded in retrieving: Q7505672 | Number of tickers left: 1013
# Trying to retrieve: Q7389686
# Succeeded in retrieving: Q7389686 | Number of tickers left: 1012
# Trying to retrieve: Q7500007
# Succeeded in retrieving: Q7500007 | Number of tickers left: 1011
# Trying to retrieve: Q7431916
# Succeeded in retrieving: Q7431916 | Number of tickers left: 1010
# Trying to retrieve: Q1155729
# Succeeded in retrieving: Q1155729 | Number of tickers left: 1009
# Trying to retrieve: Q37158
# Succeeded in retrieving: Q37158 | Number of tickers left: 1008
# Trying to retrieve: Q2288792
# Succeeded in retrieving: Q2288792 | Number of tickers left: 1007
# Trying to retrieve: Q1190598
# Succeeded in retrieving: Q1190598 | Number of tickers left: 1006
# Trying to retrieve: Q1280748
# Succeeded in retrieving: Q1280748 | Number of tickers left: 1005
# Trying to retrieve: Q17109642
# Succeeded in retrieving: Q17109642 | Number of tickers left: 1004
# Trying to retrieve: Q426583
# Succeeded in retrieving: Q426583 | Number of tickers left: 1003
# Trying to retrieve: Q7399844
# Succeeded in retrieving: Q7399844 | Number of tickers left: 1002
# Trying to retrieve: Q20022777
# Succeeded in retrieving: Q20022777 | Number of tickers left: 1001
# Trying to retrieve: Q170614
# Succeeded in retrieving: Q170614 | Number of tickers left: 1000
# Trying to retrieve: Q7382830
# Succeeded in retrieving: Q7382830 | Number of tickers left: 999
# Trying to retrieve: Q7304886
# Succeeded in retrieving: Q7304886 | Number of tickers left: 998
# Trying to retrieve: Q7277601
# Succeeded in retrieving: Q7277601 | Number of tickers left: 997
# Trying to retrieve: Q3442791
# Succeeded in retrieving: Q3442791 | Number of tickers left: 996
# Trying to retrieve: Q20656950
# Failed in retrieving: Q20656950 | Number of tickers left: 995
# Retrying
# Trying to retrieve: Q7374224
# Succeeded in retrieving: Q7374224 | Number of tickers left: 994
# Trying to retrieve: Q17078090
# Succeeded in retrieving: Q17078090 | Number of tickers left: 993
# Trying to retrieve: Q7308054
# Succeeded in retrieving: Q7308054 | Number of tickers left: 992
# Trying to retrieve: Q2228136
# Succeeded in retrieving: Q2228136 | Number of tickers left: 991
# Trying to retrieve: Q2907743
# Succeeded in retrieving: Q2907743 | Number of tickers left: 990
# Trying to retrieve: Q7355744
# Succeeded in retrieving: Q7355744 | Number of tickers left: 989
# Trying to retrieve: Q7313497
# Succeeded in retrieving: Q7313497 | Number of tickers left: 988
# Trying to retrieve: Q7314387
# Succeeded in retrieving: Q7314387 | Number of tickers left: 987
# Trying to retrieve: Q7296403
# Succeeded in retrieving: Q7296403 | Number of tickers left: 986
# Trying to retrieve: Q5501354
# Succeeded in retrieving: Q5501354 | Number of tickers left: 985
# Trying to retrieve: Q6541837
# Succeeded in retrieving: Q6541837 | Number of tickers left: 984
# Trying to retrieve: Q17109731
# Succeeded in retrieving: Q17109731 | Number of tickers left: 983
# Trying to retrieve: Q507306
# Succeeded in retrieving: Q507306 | Number of tickers left: 982
# Trying to retrieve: Q7268802
# Succeeded in retrieving: Q7268802 | Number of tickers left: 981
# Trying to retrieve: Q315287
# Succeeded in retrieving: Q315287 | Number of tickers left: 980
# Trying to retrieve: Q15917582
# Succeeded in retrieving: Q15917582 | Number of tickers left: 979
# Trying to retrieve: Q544847
# Succeeded in retrieving: Q544847 | Number of tickers left: 978
# Trying to retrieve: Q2899735
# Succeeded in retrieving: Q2899735 | Number of tickers left: 977
# Trying to retrieve: Q2759586
# Succeeded in retrieving: Q2759586 | Number of tickers left: 976
# Trying to retrieve: Q7118151
# Succeeded in retrieving: Q7118151 | Number of tickers left: 975
# Trying to retrieve: Q3370152
# Succeeded in retrieving: Q3370152 | Number of tickers left: 974
# Trying to retrieve: Q7138046
# Succeeded in retrieving: Q7138046 | Number of tickers left: 973
# Trying to retrieve: Q7242563
# Succeeded in retrieving: Q7242563 | Number of tickers left: 972
# Trying to retrieve: Q20714950
# Succeeded in retrieving: Q20714950 | Number of tickers left: 971
# Trying to retrieve: Q7168146
# Succeeded in retrieving: Q7168146 | Number of tickers left: 970
# Trying to retrieve: Q19868026
# Succeeded in retrieving: Q19868026 | Number of tickers left: 969
# Trying to retrieve: Q3388421
# Succeeded in retrieving: Q3388421 | Number of tickers left: 968
# Trying to retrieve: Q7236078
# Succeeded in retrieving: Q7236078 | Number of tickers left: 967
# Trying to retrieve: Q7196294
# Succeeded in retrieving: Q7196294 | Number of tickers left: 966
# Trying to retrieve: Q7256219
# Succeeded in retrieving: Q7256219 | Number of tickers left: 965
# Trying to retrieve: Q2099437
# Succeeded in retrieving: Q2099437 | Number of tickers left: 964
# Trying to retrieve: Q16992684
# Succeeded in retrieving: Q16992684 | Number of tickers left: 963
# Trying to retrieve: Q3520257
# Succeeded in retrieving: Q3520257 | Number of tickers left: 962
# Trying to retrieve: Q7187948
# Succeeded in retrieving: Q7187948 | Number of tickers left: 961
# Trying to retrieve: Q4047452
# Succeeded in retrieving: Q4047452 | Number of tickers left: 960
# Trying to retrieve: Q7239836
# Succeeded in retrieving: Q7239836 | Number of tickers left: 959
# Trying to retrieve: Q7171526
# Succeeded in retrieving: Q7171526 | Number of tickers left: 958
# Trying to retrieve: Q7169774
# Succeeded in retrieving: Q7169774 | Number of tickers left: 957
# Trying to retrieve: Q7160600
# Succeeded in retrieving: Q7160600 | Number of tickers left: 956
# Trying to retrieve: Q7118809
# Succeeded in retrieving: Q7118809 | Number of tickers left: 955
# Trying to retrieve: Q538203
# Succeeded in retrieving: Q538203 | Number of tickers left: 954
# Trying to retrieve: Q3792482
# Succeeded in retrieving: Q3792482 | Number of tickers left: 953
# Trying to retrieve: Q7118707
# Succeeded in retrieving: Q7118707 | Number of tickers left: 952
# Trying to retrieve: Q18674747
# Succeeded in retrieving: Q18674747 | Number of tickers left: 951
# Trying to retrieve: Q7234972
# Succeeded in retrieving: Q7234972 | Number of tickers left: 950
# Trying to retrieve: Q1477661
# Succeeded in retrieving: Q1477661 | Number of tickers left: 949
# Trying to retrieve: Q7165802
# Succeeded in retrieving: Q7165802 | Number of tickers left: 948
# Trying to retrieve: Q946080
# Succeeded in retrieving: Q946080 | Number of tickers left: 947
# Trying to retrieve: Q17143144
# Succeeded in retrieving: Q17143144 | Number of tickers left: 946
# Trying to retrieve: Q7129613
# Succeeded in retrieving: Q7129613 | Number of tickers left: 945
# Trying to retrieve: Q7109415
# Succeeded in retrieving: Q7109415 | Number of tickers left: 944
# Trying to retrieve: Q5515077
# Succeeded in retrieving: Q5515077 | Number of tickers left: 943
# Trying to retrieve: Q3301958
# Succeeded in retrieving: Q3301958 | Number of tickers left: 942
# Trying to retrieve: Q7572694
# Succeeded in retrieving: Q7572694 | Number of tickers left: 941
# Trying to retrieve: Q7071951
# Succeeded in retrieving: Q7071951 | Number of tickers left: 940
# Trying to retrieve: Q846743
# Succeeded in retrieving: Q846743 | Number of tickers left: 939
# Trying to retrieve: Q7084595
# Succeeded in retrieving: Q7084595 | Number of tickers left: 938
# Trying to retrieve: Q1671509
# Succeeded in retrieving: Q1671509 | Number of tickers left: 937
# Trying to retrieve: Q5612176
# Succeeded in retrieving: Q5612176 | Number of tickers left: 936
# Trying to retrieve: Q3116307
# Succeeded in retrieving: Q3116307 | Number of tickers left: 935
# Trying to retrieve: Q7083862
# Succeeded in retrieving: Q7083862 | Number of tickers left: 934
# Trying to retrieve: Q5374115
# Succeeded in retrieving: Q5374115 | Number of tickers left: 933
# Trying to retrieve: Q7070744
# Succeeded in retrieving: Q7070744 | Number of tickers left: 932
# Trying to retrieve: Q7020906
# Succeeded in retrieving: Q7020906 | Number of tickers left: 931
# Trying to retrieve: Q1155668
# Succeeded in retrieving: Q1155668 | Number of tickers left: 930
# Trying to retrieve: Q7060191
# Succeeded in retrieving: Q7060191 | Number of tickers left: 929
# Trying to retrieve: Q7064069
# Succeeded in retrieving: Q7064069 | Number of tickers left: 928
# Trying to retrieve: Q182477
# Succeeded in retrieving: Q182477 | Number of tickers left: 927
# Trying to retrieve: Q7067716
# Succeeded in retrieving: Q7067716 | Number of tickers left: 926
# Trying to retrieve: Q1137289
# Succeeded in retrieving: Q1137289 | Number of tickers left: 925
# Trying to retrieve: Q970695
# Succeeded in retrieving: Q970695 | Number of tickers left: 924
# Trying to retrieve: Q7070498
# Succeeded in retrieving: Q7070498 | Number of tickers left: 923
# Trying to retrieve: Q979690
# Succeeded in retrieving: Q979690 | Number of tickers left: 922
# Trying to retrieve: Q196259
# Succeeded in retrieving: Q196259 | Number of tickers left: 921
# Trying to retrieve: Q6998317
# Succeeded in retrieving: Q6998317 | Number of tickers left: 920
# Trying to retrieve: Q727883
# Succeeded in retrieving: Q727883 | Number of tickers left: 919
# Trying to retrieve: Q6038080
# Succeeded in retrieving: Q6038080 | Number of tickers left: 918
# Trying to retrieve: Q17114308
# Succeeded in retrieving: Q17114308 | Number of tickers left: 917
# Trying to retrieve: Q2091479
# Succeeded in retrieving: Q2091479 | Number of tickers left: 916
# Trying to retrieve: Q907311
# Succeeded in retrieving: Q907311 | Number of tickers left: 915
# Trying to retrieve: Q17114199
# Succeeded in retrieving: Q17114199 | Number of tickers left: 914
# Trying to retrieve: Q1998662
# Succeeded in retrieving: Q1998662 | Number of tickers left: 913
# Trying to retrieve: Q1472929
# Succeeded in retrieving: Q1472929 | Number of tickers left: 912
# Trying to retrieve: Q6971495
# Succeeded in retrieving: Q6971495 | Number of tickers left: 911
# Trying to retrieve: Q6952868
# Succeeded in retrieving: Q6952868 | Number of tickers left: 910
# Trying to retrieve: Q7002174
# Succeeded in retrieving: Q7002174 | Number of tickers left: 909
# Trying to retrieve: Q4045079
# Succeeded in retrieving: Q4045079 | Number of tickers left: 908
# Trying to retrieve: Q1544413
# Succeeded in retrieving: Q1544413 | Number of tickers left: 907
# Trying to retrieve: Q1319505
# Succeeded in retrieving: Q1319505 | Number of tickers left: 906
# Trying to retrieve: Q3331496
# Succeeded in retrieving: Q3331496 | Number of tickers left: 905
# Trying to retrieve: Q1784671
# Succeeded in retrieving: Q1784671 | Number of tickers left: 904
# Trying to retrieve: Q1197548
# Succeeded in retrieving: Q1197548 | Number of tickers left: 903
# Trying to retrieve: Q1881941
# Succeeded in retrieving: Q1881941 | Number of tickers left: 902
# Trying to retrieve: Q3372572
# Succeeded in retrieving: Q3372572 | Number of tickers left: 901
# Trying to retrieve: Q1192211
# Succeeded in retrieving: Q1192211 | Number of tickers left: 900
# Trying to retrieve: Q2283
# Succeeded in retrieving: Q2283 | Number of tickers left: 899
# Trying to retrieve: Q8178679
# Succeeded in retrieving: Q8178679 | Number of tickers left: 898
# Trying to retrieve: Q17113791
# Succeeded in retrieving: Q17113791 | Number of tickers left: 897
# Trying to retrieve: Q6840048
# Succeeded in retrieving: Q6840048 | Number of tickers left: 896
# Trying to retrieve: Q1347782
# Succeeded in retrieving: Q1347782 | Number of tickers left: 895
# Trying to retrieve: Q6818651
# Succeeded in retrieving: Q6818651 | Number of tickers left: 894
# Trying to retrieve: Q1389504
# Succeeded in retrieving: Q1389504 | Number of tickers left: 893
# Trying to retrieve: Q6843476
# Succeeded in retrieving: Q6843476 | Number of tickers left: 892
# Trying to retrieve: Q6902090
# Succeeded in retrieving: Q6902090 | Number of tickers left: 891
# Trying to retrieve: Q13115286
# Wikidata redirect detected.  Input entity id=Q13115286. Returned entity id=Q3630923.
# Succeeded in retrieving: Q13115286 | Number of tickers left: 890
# Trying to retrieve: Q7680886
# Succeeded in retrieving: Q7680886 | Number of tickers left: 889
# Trying to retrieve: Q489469
# Succeeded in retrieving: Q489469 | Number of tickers left: 888
# Trying to retrieve: Q6735371
# Succeeded in retrieving: Q6735371 | Number of tickers left: 887
# Trying to retrieve: Q20047296
# Succeeded in retrieving: Q20047296 | Number of tickers left: 886
# Trying to retrieve: Q6715705
# Succeeded in retrieving: Q6715705 | Number of tickers left: 885
# Trying to retrieve: Q1391599
# Succeeded in retrieving: Q1391599 | Number of tickers left: 884
# Trying to retrieve: Q13529431
# Succeeded in retrieving: Q13529431 | Number of tickers left: 883
# Trying to retrieve: Q950419
# Succeeded in retrieving: Q950419 | Number of tickers left: 882
# Trying to retrieve: Q6806791
# Succeeded in retrieving: Q6806791 | Number of tickers left: 881
# Trying to retrieve: Q4733274
# Failed in retrieving: Q4733274 | Number of tickers left: 880
# Retrying
# Succeeded in retrieving: Q4733274 | Number of tickers left: 880
# Trying to retrieve: Q12857502
# Succeeded in retrieving: Q12857502 | Number of tickers left: 879
# Trying to retrieve: Q4816705
# Succeeded in retrieving: Q4816705 | Number of tickers left: 878
# Trying to retrieve: Q1545076
# Succeeded in retrieving: Q1545076 | Number of tickers left: 877
# Trying to retrieve: Q596139
# Succeeded in retrieving: Q596139 | Number of tickers left: 876
# Trying to retrieve: Q6783278
# Succeeded in retrieving: Q6783278 | Number of tickers left: 875
# Trying to retrieve: Q1141173
# Succeeded in retrieving: Q1141173 | Number of tickers left: 874
# Trying to retrieve: Q6746136
# Succeeded in retrieving: Q6746136 | Number of tickers left: 873
# Trying to retrieve: Q3285819
# Succeeded in retrieving: Q3285819 | Number of tickers left: 872
# Trying to retrieve: Q6537727
# Succeeded in retrieving: Q6537727 | Number of tickers left: 871
# Trying to retrieve: Q6545549
# Succeeded in retrieving: Q6545549 | Number of tickers left: 870
# Trying to retrieve: Q6702957
# Succeeded in retrieving: Q6702957 | Number of tickers left: 869
# Trying to retrieve: Q6485221
# Succeeded in retrieving: Q6485221 | Number of tickers left: 868
# Trying to retrieve: Q1342041
# Succeeded in retrieving: Q1342041 | Number of tickers left: 867
# Trying to retrieve: Q4744658
# Succeeded in retrieving: Q4744658 | Number of tickers left: 866
# Trying to retrieve: Q6459734
# Succeeded in retrieving: Q6459734 | Number of tickers left: 865
# Trying to retrieve: Q3259355
# Succeeded in retrieving: Q3259355 | Number of tickers left: 864
# Trying to retrieve: Q33129672
# Succeeded in retrieving: Q33129672 | Number of tickers left: 863
# Trying to retrieve: Q5173965
# Succeeded in retrieving: Q5173965 | Number of tickers left: 862
# Trying to retrieve: Q223127
# Succeeded in retrieving: Q223127 | Number of tickers left: 861
# Trying to retrieve: Q7548877
# Succeeded in retrieving: Q7548877 | Number of tickers left: 860
# Trying to retrieve: Q6703383
# Succeeded in retrieving: Q6703383 | Number of tickers left: 859
# Trying to retrieve: Q20711490
# Succeeded in retrieving: Q20711490 | Number of tickers left: 858
# Trying to retrieve: Q16250432
# Succeeded in retrieving: Q16250432 | Number of tickers left: 857
# Trying to retrieve: Q6648755
# Succeeded in retrieving: Q6648755 | Number of tickers left: 856
# Trying to retrieve: Q6550657
# Succeeded in retrieving: Q6550657 | Number of tickers left: 855
# Trying to retrieve: Q7668516
# Succeeded in retrieving: Q7668516 | Number of tickers left: 854
# Trying to retrieve: Q1740323
# Succeeded in retrieving: Q1740323 | Number of tickers left: 853
# Trying to retrieve: Q624649
# Succeeded in retrieving: Q624649 | Number of tickers left: 852
# Trying to retrieve: Q6415714
# Succeeded in retrieving: Q6415714 | Number of tickers left: 851
# Trying to retrieve: Q6398722
# Failed in retrieving: Q6398722 | Number of tickers left: 850
# Retrying
# Succeeded in retrieving: Q6398722 | Number of tickers left: 850
# Trying to retrieve: Q1538585
# Succeeded in retrieving: Q1538585 | Number of tickers left: 849
# Trying to retrieve: Q1526456
# Succeeded in retrieving: Q1526456 | Number of tickers left: 848
# Trying to retrieve: Q6348410
# Succeeded in retrieving: Q6348410 | Number of tickers left: 847
# Trying to retrieve: Q19654979
# Succeeded in retrieving: Q19654979 | Number of tickers left: 846
# Trying to retrieve: Q3088784
# Succeeded in retrieving: Q3088784 | Number of tickers left: 845
# Trying to retrieve: Q6113060
# Succeeded in retrieving: Q6113060 | Number of tickers left: 844
# Trying to retrieve: Q6109309
# Succeeded in retrieving: Q6109309 | Number of tickers left: 843
# Trying to retrieve: Q16997523
# Succeeded in retrieving: Q16997523 | Number of tickers left: 842
# Trying to retrieve: Q161086
# Succeeded in retrieving: Q161086 | Number of tickers left: 841
# Trying to retrieve: Q4041705
# Succeeded in retrieving: Q4041705 | Number of tickers left: 840
# Trying to retrieve: Q16255113
# Succeeded in retrieving: Q16255113 | Number of tickers left: 839
# Trying to retrieve: Q1538507
# Succeeded in retrieving: Q1538507 | Number of tickers left: 838
# Trying to retrieve: Q16974955
# Succeeded in retrieving: Q16974955 | Number of tickers left: 837
# Trying to retrieve: Q5923178
# Succeeded in retrieving: Q5923178 | Number of tickers left: 836
# Trying to retrieve: Q2743863
# Succeeded in retrieving: Q2743863 | Number of tickers left: 835
# Trying to retrieve: Q974211
# Succeeded in retrieving: Q974211 | Number of tickers left: 834
# Trying to retrieve: Q154387
# Succeeded in retrieving: Q154387 | Number of tickers left: 833
# Trying to retrieve: Q285161
# Succeeded in retrieving: Q285161 | Number of tickers left: 832
# Trying to retrieve: Q16996714
# Failed in retrieving: Q16996714 | Number of tickers left: 831
# Retrying
# Succeeded in retrieving: Q16996714 | Number of tickers left: 831
# Trying to retrieve: Q5973024
# Succeeded in retrieving: Q5973024 | Number of tickers left: 830
# Trying to retrieve: Q6030036
# Failed in retrieving: Q6030036 | Number of tickers left: 829
# Retrying
# Trying to retrieve: Q15109891
# Succeeded in retrieving: Q15109891 | Number of tickers left: 828
# Trying to retrieve: Q6035325
# Succeeded in retrieving: Q6035325 | Number of tickers left: 827
# Trying to retrieve: Q1318848
# Succeeded in retrieving: Q1318848 | Number of tickers left: 826
# Trying to retrieve: Q1666331
# Succeeded in retrieving: Q1666331 | Number of tickers left: 825
# Trying to retrieve: Q248
# Succeeded in retrieving: Q248 | Number of tickers left: 824
# Trying to retrieve: Q6029685
# Succeeded in retrieving: Q6029685 | Number of tickers left: 823
# Trying to retrieve: Q7355463
# Succeeded in retrieving: Q7355463 | Number of tickers left: 822
# Trying to retrieve: Q6015591
# Succeeded in retrieving: Q6015591 | Number of tickers left: 821
# Trying to retrieve: Q5453106
# Succeeded in retrieving: Q5453106 | Number of tickers left: 820
# Trying to retrieve: Q6007092
# Succeeded in retrieving: Q6007092 | Number of tickers left: 819
# Trying to retrieve: Q6032595
# Succeeded in retrieving: Q6032595 | Number of tickers left: 818
# Trying to retrieve: Q2068984
# Succeeded in retrieving: Q2068984 | Number of tickers left: 817
# Trying to retrieve: Q5985017
# Succeeded in retrieving: Q5985017 | Number of tickers left: 816
# Trying to retrieve: Q1758392
# Succeeded in retrieving: Q1758392 | Number of tickers left: 815
# Trying to retrieve: Q1665429
# Succeeded in retrieving: Q1665429 | Number of tickers left: 814
# Trying to retrieve: Q6044894
# Succeeded in retrieving: Q6044894 | Number of tickers left: 813
# Trying to retrieve: Q5969799
# Succeeded in retrieving: Q5969799 | Number of tickers left: 812
# Trying to retrieve: Q5969562
# Succeeded in retrieving: Q5969562 | Number of tickers left: 811
# Trying to retrieve: Q6048685
# Succeeded in retrieving: Q6048685 | Number of tickers left: 810
# Trying to retrieve: Q20011294
# Succeeded in retrieving: Q20011294 | Number of tickers left: 809
# Trying to retrieve: Q5968523
# Succeeded in retrieving: Q5968523 | Number of tickers left: 808
# Trying to retrieve: Q974846
# Succeeded in retrieving: Q974846 | Number of tickers left: 807
# Trying to retrieve: Q17086972
# Succeeded in retrieving: Q17086972 | Number of tickers left: 806
# Trying to retrieve: Q17183768
# Succeeded in retrieving: Q17183768 | Number of tickers left: 805
# Trying to retrieve: Q16995776
# Succeeded in retrieving: Q16995776 | Number of tickers left: 804
# Trying to retrieve: Q452340
# Succeeded in retrieving: Q452340 | Number of tickers left: 803
# Trying to retrieve: Q17110635
# Succeeded in retrieving: Q17110635 | Number of tickers left: 802
# Trying to retrieve: Q905086
# Succeeded in retrieving: Q905086 | Number of tickers left: 801
# Trying to retrieve: Q265176
# Succeeded in retrieving: Q265176 | Number of tickers left: 800
# Trying to retrieve: Q5884072
# Succeeded in retrieving: Q5884072 | Number of tickers left: 799
# Trying to retrieve: Q5750671
# Succeeded in retrieving: Q5750671 | Number of tickers left: 798
# Trying to retrieve: Q5703474
# Succeeded in retrieving: Q5703474 | Number of tickers left: 797
# Trying to retrieve: Q5656147
# Succeeded in retrieving: Q5656147 | Number of tickers left: 796
# Trying to retrieve: Q5684575
# Succeeded in retrieving: Q5684575 | Number of tickers left: 795
# Trying to retrieve: Q5647025
# Succeeded in retrieving: Q5647025 | Number of tickers left: 794
# Trying to retrieve: Q798819
# Failed in retrieving: Q798819 | Number of tickers left: 793
# Retrying
# Succeeded in retrieving: Q798819 | Number of tickers left: 793
# Trying to retrieve: Q1591976
# Succeeded in retrieving: Q1591976 | Number of tickers left: 792
# Trying to retrieve: Q501476
# Succeeded in retrieving: Q501476 | Number of tickers left: 791
# Trying to retrieve: Q5643474
# Succeeded in retrieving: Q5643474 | Number of tickers left: 790
# Trying to retrieve: Q5639346
# Succeeded in retrieving: Q5639346 | Number of tickers left: 789
# Trying to retrieve: Q5648633
# Succeeded in retrieving: Q5648633 | Number of tickers left: 788
# Trying to retrieve: Q642610
# Succeeded in retrieving: Q642610 | Number of tickers left: 787
# Trying to retrieve: Q620875
# Succeeded in retrieving: Q620875 | Number of tickers left: 786
# Trying to retrieve: Q658789
# Succeeded in retrieving: Q658789 | Number of tickers left: 785
# Trying to retrieve: Q901262
# Succeeded in retrieving: Q901262 | Number of tickers left: 784
# Trying to retrieve: Q20800404
# Succeeded in retrieving: Q20800404 | Number of tickers left: 783
# Trying to retrieve: Q95
# Succeeded in retrieving: Q95 | Number of tickers left: 782
# Trying to retrieve: Q1961738
# Succeeded in retrieving: Q1961738 | Number of tickers left: 781
# Trying to retrieve: Q5512990
# Succeeded in retrieving: Q5512990 | Number of tickers left: 780
# Trying to retrieve: Q5578424
# Succeeded in retrieving: Q5578424 | Number of tickers left: 779
# Trying to retrieve: Q663596
# Succeeded in retrieving: Q663596 | Number of tickers left: 778
# Trying to retrieve: Q28175069
# Succeeded in retrieving: Q28175069 | Number of tickers left: 777
# Trying to retrieve: Q3118234
# Succeeded in retrieving: Q3118234 | Number of tickers left: 776
# Trying to retrieve: Q5579415
# Succeeded in retrieving: Q5579415 | Number of tickers left: 775
# Trying to retrieve: Q17183462
# Succeeded in retrieving: Q17183462 | Number of tickers left: 774
# Trying to retrieve: Q5508431
# Succeeded in retrieving: Q5508431 | Number of tickers left: 773
# Trying to retrieve: Q2974454
# Succeeded in retrieving: Q2974454 | Number of tickers left: 772
# Trying to retrieve: Q2749364
# Succeeded in retrieving: Q2749364 | Number of tickers left: 771
# Trying to retrieve: Q1138888
# Succeeded in retrieving: Q1138888 | Number of tickers left: 770
# Trying to retrieve: Q18636301
# Succeeded in retrieving: Q18636301 | Number of tickers left: 769
# Trying to retrieve: Q5453261
# Succeeded in retrieving: Q5453261 | Number of tickers left: 768
# Trying to retrieve: Q16976069
# Failed in retrieving: Q16976069 | Number of tickers left: 767
# Retrying
# Trying to retrieve: Q5476713
# Succeeded in retrieving: Q5476713 | Number of tickers left: 766
# Trying to retrieve: Q356212
# Succeeded in retrieving: Q356212 | Number of tickers left: 765
# Trying to retrieve: Q829961
# Succeeded in retrieving: Q829961 | Number of tickers left: 764
# Trying to retrieve: Q5453330
# Succeeded in retrieving: Q5453330 | Number of tickers left: 763
# Trying to retrieve: Q5426537
# Succeeded in retrieving: Q5426537 | Number of tickers left: 762
# Trying to retrieve: Q1140680
# Succeeded in retrieving: Q1140680 | Number of tickers left: 761
# Trying to retrieve: Q15109910
# Succeeded in retrieving: Q15109910 | Number of tickers left: 760
# Trying to retrieve: Q5455836
# Succeeded in retrieving: Q5455836 | Number of tickers left: 759
# Trying to retrieve: Q1411810
# Succeeded in retrieving: Q1411810 | Number of tickers left: 758
# Trying to retrieve: Q1420513
# Succeeded in retrieving: Q1420513 | Number of tickers left: 757
# Trying to retrieve: Q5450341
# Succeeded in retrieving: Q5450341 | Number of tickers left: 756
# Trying to retrieve: Q5453107
# Succeeded in retrieving: Q5453107 | Number of tickers left: 755
# Trying to retrieve: Q3029296
# Succeeded in retrieving: Q3029296 | Number of tickers left: 754
# Trying to retrieve: Q5453009
# Succeeded in retrieving: Q5453009 | Number of tickers left: 753
# Trying to retrieve: Q5452995
# Succeeded in retrieving: Q5452995 | Number of tickers left: 752
# Trying to retrieve: Q5452733
# Succeeded in retrieving: Q5452733 | Number of tickers left: 751
# Trying to retrieve: Q5452775
# Succeeded in retrieving: Q5452775 | Number of tickers left: 750
# Trying to retrieve: Q5452332
# Succeeded in retrieving: Q5452332 | Number of tickers left: 749
# Trying to retrieve: Q380
# Succeeded in retrieving: Q380 | Number of tickers left: 748
# Trying to retrieve: Q3067119
# Succeeded in retrieving: Q3067119 | Number of tickers left: 747
# Trying to retrieve: Q18148458
# Succeeded in retrieving: Q18148458 | Number of tickers left: 746
# Trying to retrieve: Q5421507
# Succeeded in retrieving: Q5421507 | Number of tickers left: 745
# Trying to retrieve: Q8085893
# Succeeded in retrieving: Q8085893 | Number of tickers left: 744
# Trying to retrieve: Q1384324
# Succeeded in retrieving: Q1384324 | Number of tickers left: 743
# Trying to retrieve: Q5324689
# Succeeded in retrieving: Q5324689 | Number of tickers left: 742
# Trying to retrieve: Q3061734
# Succeeded in retrieving: Q3061734 | Number of tickers left: 741
# Trying to retrieve: Q5329659
# Succeeded in retrieving: Q5329659 | Number of tickers left: 740
# Trying to retrieve: Q2607502
# Succeeded in retrieving: Q2607502 | Number of tickers left: 739
# Trying to retrieve: Q768231
# Succeeded in retrieving: Q768231 | Number of tickers left: 738
# Trying to retrieve: Q1325369
# Succeeded in retrieving: Q1325369 | Number of tickers left: 737
# Trying to retrieve: Q5388314
# Succeeded in retrieving: Q5388314 | Number of tickers left: 736
# Trying to retrieve: Q5380128
# Succeeded in retrieving: Q5380128 | Number of tickers left: 735
# Trying to retrieve: Q17114312
# Succeeded in retrieving: Q17114312 | Number of tickers left: 734
# Trying to retrieve: Q5324991
# Succeeded in retrieving: Q5324991 | Number of tickers left: 733
# Trying to retrieve: Q5358494
# Succeeded in retrieving: Q5358494 | Number of tickers left: 732
# Trying to retrieve: Q5412010
# Succeeded in retrieving: Q5412010 | Number of tickers left: 731
# Trying to retrieve: Q5375543
# Succeeded in retrieving: Q5375543 | Number of tickers left: 730
# Trying to retrieve: Q5332702
# Failed in retrieving: Q5332702 | Number of tickers left: 729
# Retrying
# Trying to retrieve: Q173941
# Succeeded in retrieving: Q173941 | Number of tickers left: 728
# Trying to retrieve: Q15109865
# Succeeded in retrieving: Q15109865 | Number of tickers left: 727
# Trying to retrieve: Q5206170
# Succeeded in retrieving: Q5206170 | Number of tickers left: 726
# Trying to retrieve: Q847743
# Succeeded in retrieving: Q847743 | Number of tickers left: 725
# Trying to retrieve: Q5275736
# Succeeded in retrieving: Q5275736 | Number of tickers left: 724
# Trying to retrieve: Q5289230
# Succeeded in retrieving: Q5289230 | Number of tickers left: 723
# Trying to retrieve: Q1199757
# Succeeded in retrieving: Q1199757 | Number of tickers left: 722
# Trying to retrieve: Q5279096
# Succeeded in retrieving: Q5279096 | Number of tickers left: 721
# Trying to retrieve: Q8041701
# Succeeded in retrieving: Q8041701 | Number of tickers left: 720
# Trying to retrieve: Q21070725
# Succeeded in retrieving: Q21070725 | Number of tickers left: 719
# Trying to retrieve: Q5277215
# Succeeded in retrieving: Q5277215 | Number of tickers left: 718
# Trying to retrieve: Q1157767
# Succeeded in retrieving: Q1157767 | Number of tickers left: 717
# Trying to retrieve: Q5072155
# Succeeded in retrieving: Q5072155 | Number of tickers left: 716
# Trying to retrieve: Q478354
# Succeeded in retrieving: Q478354 | Number of tickers left: 715
# Trying to retrieve: Q16850385
# Succeeded in retrieving: Q16850385 | Number of tickers left: 714
# Trying to retrieve: Q916196
# Succeeded in retrieving: Q916196 | Number of tickers left: 713
# Trying to retrieve: Q1107035
# Succeeded in retrieving: Q1107035 | Number of tickers left: 712
# Trying to retrieve: Q5122438
# Succeeded in retrieving: Q5122438 | Number of tickers left: 711
# Trying to retrieve: Q15109928
# Succeeded in retrieving: Q15109928 | Number of tickers left: 710
# Trying to retrieve: Q1287771
# Succeeded in retrieving: Q1287771 | Number of tickers left: 709
# Trying to retrieve: Q16988748
# Succeeded in retrieving: Q16988748 | Number of tickers left: 708
# Trying to retrieve: Q173395
# Succeeded in retrieving: Q173395 | Number of tickers left: 707
# Trying to retrieve: Q5169368
# Succeeded in retrieving: Q5169368 | Number of tickers left: 706
# Trying to retrieve: Q1067998
# Succeeded in retrieving: Q1067998 | Number of tickers left: 705
# Trying to retrieve: Q926699
# Failed in retrieving: Q926699 | Number of tickers left: 704
# Retrying
# Succeeded in retrieving: Q926699 | Number of tickers left: 704
# Trying to retrieve: Q5183828
# Succeeded in retrieving: Q5183828 | Number of tickers left: 703
# Trying to retrieve: Q144060
# Succeeded in retrieving: Q144060 | Number of tickers left: 702
# Trying to retrieve: Q5013834
# Succeeded in retrieving: Q5013834 | Number of tickers left: 701
# Trying to retrieve: Q5035257
# Failed in retrieving: Q5035257 | Number of tickers left: 700
# Retrying
# Succeeded in retrieving: Q5035257 | Number of tickers left: 700
# Trying to retrieve: Q715583
# Succeeded in retrieving: Q715583 | Number of tickers left: 699
# Trying to retrieve: Q5170128
# Succeeded in retrieving: Q5170128 | Number of tickers left: 698
# Trying to retrieve: Q5161257
# Succeeded in retrieving: Q5161257 | Number of tickers left: 697
# Trying to retrieve: Q1112588
# Succeeded in retrieving: Q1112588 | Number of tickers left: 696
# Trying to retrieve: Q5139058
# Succeeded in retrieving: Q5139058 | Number of tickers left: 695
# Trying to retrieve: Q1107088
# Succeeded in retrieving: Q1107088 | Number of tickers left: 694
# Trying to retrieve: Q2128566
# Failed in retrieving: Q2128566 | Number of tickers left: 693
# Retrying
# Succeeded in retrieving: Q2128566 | Number of tickers left: 693
# Trying to retrieve: Q1023876
# Succeeded in retrieving: Q1023876 | Number of tickers left: 692
# Trying to retrieve: Q1113804
# Succeeded in retrieving: Q1113804 | Number of tickers left: 691
# Trying to retrieve: Q5120253
# Succeeded in retrieving: Q5120253 | Number of tickers left: 690
# Trying to retrieve: Q5147194
# Succeeded in retrieving: Q5147194 | Number of tickers left: 689
# Trying to retrieve: Q5118415
# Succeeded in retrieving: Q5118415 | Number of tickers left: 688
# Trying to retrieve: Q5011381
# Succeeded in retrieving: Q5011381 | Number of tickers left: 687
# Trying to retrieve: Q931200
# Succeeded in retrieving: Q931200 | Number of tickers left: 686
# Trying to retrieve: Q176587
# Succeeded in retrieving: Q176587 | Number of tickers left: 685
# Trying to retrieve: Q5090406
# Succeeded in retrieving: Q5090406 | Number of tickers left: 684
# Trying to retrieve: Q5118174
# Succeeded in retrieving: Q5118174 | Number of tickers left: 683
# Trying to retrieve: Q2981857
# Succeeded in retrieving: Q2981857 | Number of tickers left: 682
# Trying to retrieve: Q926806
# Failed in retrieving: Q926806 | Number of tickers left: 681
# Retrying
# Succeeded in retrieving: Q926806 | Number of tickers left: 681
# Trying to retrieve: Q1055390
# Succeeded in retrieving: Q1055390 | Number of tickers left: 680
# Trying to retrieve: Q842947
# Succeeded in retrieving: Q842947 | Number of tickers left: 679
# Trying to retrieve: Q608776
# Succeeded in retrieving: Q608776 | Number of tickers left: 678
# Trying to retrieve: Q1106938
# Succeeded in retrieving: Q1106938 | Number of tickers left: 677
# Trying to retrieve: Q5152411
# Succeeded in retrieving: Q5152411 | Number of tickers left: 676
# Trying to retrieve: Q4492609
# Succeeded in retrieving: Q4492609 | Number of tickers left: 675
# Trying to retrieve: Q1071853
# Succeeded in retrieving: Q1071853 | Number of tickers left: 674
# Trying to retrieve: Q5035481
# Succeeded in retrieving: Q5035481 | Number of tickers left: 673
# Trying to retrieve: Q5055187
# Succeeded in retrieving: Q5055187 | Number of tickers left: 672
# Trying to retrieve: Q4189507
# Succeeded in retrieving: Q4189507 | Number of tickers left: 671
# Trying to retrieve: Q2940968
# Succeeded in retrieving: Q2940968 | Number of tickers left: 670
# Trying to retrieve: Q6822267
# Succeeded in retrieving: Q6822267 | Number of tickers left: 669
# Trying to retrieve: Q5038056
# Succeeded in retrieving: Q5038056 | Number of tickers left: 668
# Trying to retrieve: Q2874395
# Succeeded in retrieving: Q2874395 | Number of tickers left: 667
# Trying to retrieve: Q5018092
# Succeeded in retrieving: Q5018092 | Number of tickers left: 666
# Trying to retrieve: Q7939183
# Succeeded in retrieving: Q7939183 | Number of tickers left: 665
# Trying to retrieve: Q1045842
# Succeeded in retrieving: Q1045842 | Number of tickers left: 664
# Trying to retrieve: Q15845093
# Succeeded in retrieving: Q15845093 | Number of tickers left: 663
# Trying to retrieve: Q600624
# Succeeded in retrieving: Q600624 | Number of tickers left: 662
# Trying to retrieve: Q509255
# Succeeded in retrieving: Q509255 | Number of tickers left: 661
# Trying to retrieve: Q5001347
# Succeeded in retrieving: Q5001347 | Number of tickers left: 660
# Trying to retrieve: Q4868109
# Succeeded in retrieving: Q4868109 | Number of tickers left: 659
# Trying to retrieve: Q431454
# Succeeded in retrieving: Q431454 | Number of tickers left: 658
# Trying to retrieve: Q7998742
# Succeeded in retrieving: Q7998742 | Number of tickers left: 657
# Trying to retrieve: Q2424396
# Succeeded in retrieving: Q2424396 | Number of tickers left: 656
# Trying to retrieve: Q7229656
# Succeeded in retrieving: Q7229656 | Number of tickers left: 655
# Trying to retrieve: Q5318916
# Succeeded in retrieving: Q5318916 | Number of tickers left: 654
# Trying to retrieve: Q2162158
# Succeeded in retrieving: Q2162158 | Number of tickers left: 653
# Trying to retrieve: Q4937270
# Succeeded in retrieving: Q4937270 | Number of tickers left: 652
# Trying to retrieve: Q4932386
# Succeeded in retrieving: Q4932386 | Number of tickers left: 651
# Trying to retrieve: Q18156655
# Succeeded in retrieving: Q18156655 | Number of tickers left: 650
# Trying to retrieve: Q4914632
# Succeeded in retrieving: Q4914632 | Number of tickers left: 649
# Trying to retrieve: Q4928282
# Succeeded in retrieving: Q4928282 | Number of tickers left: 648
# Trying to retrieve: Q4922539
# Succeeded in retrieving: Q4922539 | Number of tickers left: 647
# Trying to retrieve: Q6386533
# Succeeded in retrieving: Q6386533 | Number of tickers left: 646
# Trying to retrieve: Q4835755
# Succeeded in retrieving: Q4835755 | Number of tickers left: 645
# Trying to retrieve: Q864338
# Succeeded in retrieving: Q864338 | Number of tickers left: 644
# Trying to retrieve: Q14772
# Succeeded in retrieving: Q14772 | Number of tickers left: 643
# Trying to retrieve: Q4904902
# Succeeded in retrieving: Q4904902 | Number of tickers left: 642
# Trying to retrieve: Q813782
# Succeeded in retrieving: Q813782 | Number of tickers left: 641
# Trying to retrieve: Q4854030
# Succeeded in retrieving: Q4854030 | Number of tickers left: 640
# Trying to retrieve: Q4828605
# Succeeded in retrieving: Q4828605 | Number of tickers left: 639
# Trying to retrieve: Q919300
# Succeeded in retrieving: Q919300 | Number of tickers left: 638
# Trying to retrieve: Q344341
# Succeeded in retrieving: Q344341 | Number of tickers left: 637
# Trying to retrieve: Q4816569
# Succeeded in retrieving: Q4816569 | Number of tickers left: 636
# Trying to retrieve: Q4813401
# Succeeded in retrieving: Q4813401 | Number of tickers left: 635
# Trying to retrieve: Q7077162
# Succeeded in retrieving: Q7077162 | Number of tickers left: 634
# Trying to retrieve: Q297879
# Succeeded in retrieving: Q297879 | Number of tickers left: 633
# Trying to retrieve: Q4788901
# Succeeded in retrieving: Q4788901 | Number of tickers left: 632
# Trying to retrieve: Q4789079
# Succeeded in retrieving: Q4789079 | Number of tickers left: 631
# Trying to retrieve: Q4650296
# Succeeded in retrieving: Q4650296 | Number of tickers left: 630
# Trying to retrieve: Q295774
# Succeeded in retrieving: Q295774 | Number of tickers left: 629
# Trying to retrieve: Q7713699
# Succeeded in retrieving: Q7713699 | Number of tickers left: 628
# Trying to retrieve: Q4744566
# Succeeded in retrieving: Q4744566 | Number of tickers left: 627
# Trying to retrieve: Q3884
# Succeeded in retrieving: Q3884 | Number of tickers left: 626
# Trying to retrieve: Q4745391
# Succeeded in retrieving: Q4745391 | Number of tickers left: 625
# Trying to retrieve: Q470517
# Succeeded in retrieving: Q470517 | Number of tickers left: 624
# Trying to retrieve: Q4742102
# Succeeded in retrieving: Q4742102 | Number of tickers left: 623
# Trying to retrieve: Q4652575
# Succeeded in retrieving: Q4652575 | Number of tickers left: 622
# Trying to retrieve: Q4741030
# Succeeded in retrieving: Q4741030 | Number of tickers left: 621
# Trying to retrieve: Q7449678
# Succeeded in retrieving: Q7449678 | Number of tickers left: 620
# Trying to retrieve: Q16974741
# Succeeded in retrieving: Q16974741 | Number of tickers left: 619
# Trying to retrieve: Q204727
# Succeeded in retrieving: Q204727 | Number of tickers left: 618
# Trying to retrieve: Q4751068
# Succeeded in retrieving: Q4751068 | Number of tickers left: 617
# Trying to retrieve: Q16974682
# Succeeded in retrieving: Q16974682 | Number of tickers left: 616
# Trying to retrieve: Q4727688
# Succeeded in retrieving: Q4727688 | Number of tickers left: 615
# Trying to retrieve: Q415598
# Succeeded in retrieving: Q415598 | Number of tickers left: 614
# Trying to retrieve: Q17049669
# Succeeded in retrieving: Q17049669 | Number of tickers left: 613
# Trying to retrieve: Q4738904
# Succeeded in retrieving: Q4738904 | Number of tickers left: 612
# Trying to retrieve: Q4686194
# Succeeded in retrieving: Q4686194 | Number of tickers left: 611
# Trying to retrieve: Q22060267
# Succeeded in retrieving: Q22060267 | Number of tickers left: 610
# Trying to retrieve: Q4651203
# Succeeded in retrieving: Q4651203 | Number of tickers left: 609
# Trying to retrieve: Q628051
# Succeeded in retrieving: Q628051 | Number of tickers left: 608
# Trying to retrieve: Q6394386
# Failed in retrieving: Q6394386 | Number of tickers left: 607
# Retrying
# Trying to retrieve: Q484930
# Succeeded in retrieving: Q484930 | Number of tickers left: 606
# Trying to retrieve: Q11463
# Succeeded in retrieving: Q11463 | Number of tickers left: 605
# Trying to retrieve: Q344935
# Succeeded in retrieving: Q344935 | Number of tickers left: 604
# Trying to retrieve: Q5969568
# Succeeded in retrieving: Q5969568 | Number of tickers left: 603
# Trying to retrieve: Q4674531
# Succeeded in retrieving: Q4674531 | Number of tickers left: 602
# Trying to retrieve: Q4650685
# Succeeded in retrieving: Q4650685 | Number of tickers left: 601
# ...
# Trying to retrieve: Q496302
# Succeeded in retrieving: Q496302 | Number of tickers left: 172
# Trying to retrieve: Q844805
# Succeeded in retrieving: Q844805 | Number of tickers left: 171
# Trying to retrieve: Q1206686
# Succeeded in retrieving: Q1206686 | Number of tickers left: 170
# Trying to retrieve: Q853958
# Succeeded in retrieving: Q853958 | Number of tickers left: 169
# Trying to retrieve: Q5295362
# Succeeded in retrieving: Q5295362 | Number of tickers left: 168
# Trying to retrieve: Q66048
# Succeeded in retrieving: Q66048 | Number of tickers left: 167
# Trying to retrieve: Q5214701
# Succeeded in retrieving: Q5214701 | Number of tickers left: 166
# Trying to retrieve: Q188920
# Succeeded in retrieving: Q188920 | Number of tickers left: 165
# Trying to retrieve: Q677464
# Succeeded in retrieving: Q677464 | Number of tickers left: 164
# Trying to retrieve: Q1135278
# Succeeded in retrieving: Q1135278 | Number of tickers left: 163
# Trying to retrieve: Q1138291
# Succeeded in retrieving: Q1138291 | Number of tickers left: 162
# Trying to retrieve: Q319642
# Succeeded in retrieving: Q319642 | Number of tickers left: 161
# Trying to retrieve: Q624375
# Succeeded in retrieving: Q624375 | Number of tickers left: 160
# Trying to retrieve: Q1129426
# Succeeded in retrieving: Q1129426 | Number of tickers left: 159
# Trying to retrieve: Q5178840
# Succeeded in retrieving: Q5178840 | Number of tickers left: 158
# Trying to retrieve: Q5192200
# Succeeded in retrieving: Q5192200 | Number of tickers left: 157
# Trying to retrieve: Q5192235
# Succeeded in retrieving: Q5192235 | Number of tickers left: 156
# Trying to retrieve: Q1129847
# Succeeded in retrieving: Q1129847 | Number of tickers left: 155
# Trying to retrieve: Q5035662
# Succeeded in retrieving: Q5035662 | Number of tickers left: 154
# Trying to retrieve: Q5014304
# Succeeded in retrieving: Q5014304 | Number of tickers left: 153
# Trying to retrieve: Q5041354
# Succeeded in retrieving: Q5041354 | Number of tickers left: 152
# Trying to retrieve: Q372657
# Succeeded in retrieving: Q372657 | Number of tickers left: 151
# Trying to retrieve: Q941127
# Succeeded in retrieving: Q941127 | Number of tickers left: 150
# Trying to retrieve: Q5082076
# Succeeded in retrieving: Q5082076 | Number of tickers left: 149
# Trying to retrieve: Q1053299
# Succeeded in retrieving: Q1053299 | Number of tickers left: 148
# Trying to retrieve: Q5025803
# Succeeded in retrieving: Q5025803 | Number of tickers left: 147
# Trying to retrieve: Q5023914
# Succeeded in retrieving: Q5023914 | Number of tickers left: 146
# Trying to retrieve: Q1121216
# Succeeded in retrieving: Q1121216 | Number of tickers left: 145
# Trying to retrieve: Q5061578
# Succeeded in retrieving: Q5061578 | Number of tickers left: 144
# Trying to retrieve: Q214763
# Failed in retrieving: Q214763 | Number of tickers left: 143
# Retrying
# Succeeded in retrieving: Q214763 | Number of tickers left: 143
# Trying to retrieve: Q461210
# Succeeded in retrieving: Q461210 | Number of tickers left: 142
# Trying to retrieve: Q1034654
# Succeeded in retrieving: Q1034654 | Number of tickers left: 141
# Trying to retrieve: Q1032229
# Succeeded in retrieving: Q1032229 | Number of tickers left: 140
# Trying to retrieve: Q5059102
# Succeeded in retrieving: Q5059102 | Number of tickers left: 139
# Trying to retrieve: Q5013012
# Succeeded in retrieving: Q5013012 | Number of tickers left: 138
# Trying to retrieve: Q173476
# Succeeded in retrieving: Q173476 | Number of tickers left: 137
# Trying to retrieve: Q465751
# Succeeded in retrieving: Q465751 | Number of tickers left: 136
# Trying to retrieve: Q1114148
# Succeeded in retrieving: Q1114148 | Number of tickers left: 135
# Trying to retrieve: Q666694
# Succeeded in retrieving: Q666694 | Number of tickers left: 134
# Trying to retrieve: Q910368
# Succeeded in retrieving: Q910368 | Number of tickers left: 133
# Trying to retrieve: Q5130952
# Succeeded in retrieving: Q5130952 | Number of tickers left: 132
# Trying to retrieve: Q5130494
# Succeeded in retrieving: Q5130494 | Number of tickers left: 131
# Trying to retrieve: Q609466
# Succeeded in retrieving: Q609466 | Number of tickers left: 130
# Trying to retrieve: Q806206
# Succeeded in retrieving: Q806206 | Number of tickers left: 129
# Trying to retrieve: Q1068485
# Succeeded in retrieving: Q1068485 | Number of tickers left: 128
# Trying to retrieve: Q741618
# Succeeded in retrieving: Q741618 | Number of tickers left: 127
# Trying to retrieve: Q1075788
# Succeeded in retrieving: Q1075788 | Number of tickers left: 126
# Trying to retrieve: Q5506152
# Succeeded in retrieving: Q5506152 | Number of tickers left: 125
# Trying to retrieve: Q905806
# Succeeded in retrieving: Q905806 | Number of tickers left: 124
# Trying to retrieve: Q795221
# Succeeded in retrieving: Q795221 | Number of tickers left: 123
# Trying to retrieve: Q291796
# Succeeded in retrieving: Q291796 | Number of tickers left: 122
# Trying to retrieve: Q1044059
# Succeeded in retrieving: Q1044059 | Number of tickers left: 121
# Trying to retrieve: Q5189378
# Succeeded in retrieving: Q5189378 | Number of tickers left: 120
# Trying to retrieve: Q1028449
# Succeeded in retrieving: Q1028449 | Number of tickers left: 119
# Trying to retrieve: Q950380
# Succeeded in retrieving: Q950380 | Number of tickers left: 118
# Trying to retrieve: Q5009135
# Succeeded in retrieving: Q5009135 | Number of tickers left: 117
# Trying to retrieve: Q5095516
# Succeeded in retrieving: Q5095516 | Number of tickers left: 116
# Trying to retrieve: Q1023013
# Succeeded in retrieving: Q1023013 | Number of tickers left: 115
# Trying to retrieve: Q459965
# Succeeded in retrieving: Q459965 | Number of tickers left: 114
# Trying to retrieve: Q4112833
# Succeeded in retrieving: Q4112833 | Number of tickers left: 113
# Trying to retrieve: Q62621
# Succeeded in retrieving: Q62621 | Number of tickers left: 112
# Trying to retrieve: Q1123399
# Succeeded in retrieving: Q1123399 | Number of tickers left: 111
# Trying to retrieve: Q219508
# Succeeded in retrieving: Q219508 | Number of tickers left: 110
# Trying to retrieve: Q880942
# Succeeded in retrieving: Q880942 | Number of tickers left: 109
# Trying to retrieve: Q825943
# Succeeded in retrieving: Q825943 | Number of tickers left: 108
# Trying to retrieve: Q128738
# Succeeded in retrieving: Q128738 | Number of tickers left: 107
# Trying to retrieve: Q593786
# Succeeded in retrieving: Q593786 | Number of tickers left: 106
# Trying to retrieve: Q894585
# Succeeded in retrieving: Q894585 | Number of tickers left: 105
# Trying to retrieve: Q899097
# Succeeded in retrieving: Q899097 | Number of tickers left: 104
# Trying to retrieve: Q897097
# Succeeded in retrieving: Q897097 | Number of tickers left: 103
# Trying to retrieve: Q4836297
# Succeeded in retrieving: Q4836297 | Number of tickers left: 102
# Trying to retrieve: Q4983090
# Succeeded in retrieving: Q4983090 | Number of tickers left: 101
# Trying to retrieve: Q4966553
# Succeeded in retrieving: Q4966553 | Number of tickers left: 100
# Trying to retrieve: Q1049970
# Succeeded in retrieving: Q1049970 | Number of tickers left: 99
# Trying to retrieve: Q4856124
# Succeeded in retrieving: Q4856124 | Number of tickers left: 98
# Trying to retrieve: Q451476
# Succeeded in retrieving: Q451476 | Number of tickers left: 97
# Trying to retrieve: Q266423
# Succeeded in retrieving: Q266423 | Number of tickers left: 96
# Trying to retrieve: Q806693
# Succeeded in retrieving: Q806693 | Number of tickers left: 95
# Trying to retrieve: Q2335199
# Succeeded in retrieving: Q2335199 | Number of tickers left: 94
# Trying to retrieve: Q4034815
# Succeeded in retrieving: Q4034815 | Number of tickers left: 93
# Trying to retrieve: Q219635
# Succeeded in retrieving: Q219635 | Number of tickers left: 92
# Trying to retrieve: Q795454
# Failed in retrieving: Q795454 | Number of tickers left: 91
# Retrying
# Succeeded in retrieving: Q795454 | Number of tickers left: 91
# Trying to retrieve: Q4983306
# Succeeded in retrieving: Q4983306 | Number of tickers left: 90
# Trying to retrieve: Q2904022
# Succeeded in retrieving: Q2904022 | Number of tickers left: 89
# Trying to retrieve: Q4905973
# Succeeded in retrieving: Q4905973 | Number of tickers left: 88
# Trying to retrieve: Q654762
# Succeeded in retrieving: Q654762 | Number of tickers left: 87
# Trying to retrieve: Q4886950
# Succeeded in retrieving: Q4886950 | Number of tickers left: 86
# Trying to retrieve: Q4906978
# Succeeded in retrieving: Q4906978 | Number of tickers left: 85
# Trying to retrieve: Q915543
# Succeeded in retrieving: Q915543 | Number of tickers left: 84
# Trying to retrieve: Q1009458
# Succeeded in retrieving: Q1009458 | Number of tickers left: 83
# Trying to retrieve: Q744683
# Succeeded in retrieving: Q744683 | Number of tickers left: 82
# Trying to retrieve: Q4045977
# Succeeded in retrieving: Q4045977 | Number of tickers left: 81
# Trying to retrieve: Q813780
# Succeeded in retrieving: Q813780 | Number of tickers left: 80
# Trying to retrieve: Q4957288
# Succeeded in retrieving: Q4957288 | Number of tickers left: 79
# Trying to retrieve: Q245343
# Succeeded in retrieving: Q245343 | Number of tickers left: 78
# Trying to retrieve: Q5006774
# Succeeded in retrieving: Q5006774 | Number of tickers left: 77
# Trying to retrieve: Q2902305
# Succeeded in retrieving: Q2902305 | Number of tickers left: 76
# Trying to retrieve: Q815694
# Succeeded in retrieving: Q815694 | Number of tickers left: 75
# Trying to retrieve: Q994153
# Succeeded in retrieving: Q994153 | Number of tickers left: 74
# Trying to retrieve: Q533415
# Succeeded in retrieving: Q533415 | Number of tickers left: 73
# Trying to retrieve: Q806189
# Succeeded in retrieving: Q806189 | Number of tickers left: 72
# Trying to retrieve: Q795486
# Succeeded in retrieving: Q795486 | Number of tickers left: 71
# Trying to retrieve: Q625713
# Succeeded in retrieving: Q625713 | Number of tickers left: 70
# Trying to retrieve: Q908324
# Succeeded in retrieving: Q908324 | Number of tickers left: 69
# Trying to retrieve: Q893221
# Succeeded in retrieving: Q893221 | Number of tickers left: 68
# Trying to retrieve: Q487907
# Succeeded in retrieving: Q487907 | Number of tickers left: 67
# Trying to retrieve: Q66
# Succeeded in retrieving: Q66 | Number of tickers left: 66
# Trying to retrieve: Q4861529
# Succeeded in retrieving: Q4861529 | Number of tickers left: 65
# Trying to retrieve: Q4826087
# Succeeded in retrieving: Q4826087 | Number of tickers left: 64
# Trying to retrieve: Q731938
# Succeeded in retrieving: Q731938 | Number of tickers left: 63
# Trying to retrieve: Q13583352
# Succeeded in retrieving: Q13583352 | Number of tickers left: 62
# Trying to retrieve: Q4677870
# Succeeded in retrieving: Q4677870 | Number of tickers left: 61
# Trying to retrieve: Q194360
# Failed in retrieving: Q194360 | Number of tickers left: 60
# Retrying
# Succeeded in retrieving: Q194360 | Number of tickers left: 60
# Trying to retrieve: Q4743120
# Succeeded in retrieving: Q4743120 | Number of tickers left: 59
# Trying to retrieve: Q467238
# Succeeded in retrieving: Q467238 | Number of tickers left: 58
# Trying to retrieve: Q689446
# Succeeded in retrieving: Q689446 | Number of tickers left: 57
# Trying to retrieve: Q790650
# Succeeded in retrieving: Q790650 | Number of tickers left: 56
# Trying to retrieve: Q4829076
# Succeeded in retrieving: Q4829076 | Number of tickers left: 55
# Trying to retrieve: Q4827537
# Succeeded in retrieving: Q4827537 | Number of tickers left: 54
# Trying to retrieve: Q4828988
# Succeeded in retrieving: Q4828988 | Number of tickers left: 53
# Trying to retrieve: Q541076
# Succeeded in retrieving: Q541076 | Number of tickers left: 52
# Trying to retrieve: Q1361648
# Succeeded in retrieving: Q1361648 | Number of tickers left: 51
# Trying to retrieve: Q2059537
# Succeeded in retrieving: Q2059537 | Number of tickers left: 50
# Trying to retrieve: Q25104597
# Succeeded in retrieving: Q25104597 | Number of tickers left: 49
# Trying to retrieve: Q619121
# Succeeded in retrieving: Q619121 | Number of tickers left: 48
# Trying to retrieve: Q407744
# Succeeded in retrieving: Q407744 | Number of tickers left: 47
# Trying to retrieve: Q483637
# Succeeded in retrieving: Q483637 | Number of tickers left: 46
# Trying to retrieve: Q119991
# Succeeded in retrieving: Q119991 | Number of tickers left: 45
# Trying to retrieve: Q4748076
# Succeeded in retrieving: Q4748076 | Number of tickers left: 44
# Trying to retrieve: Q739518
# Succeeded in retrieving: Q739518 | Number of tickers left: 43
# Trying to retrieve: Q677488
# Succeeded in retrieving: Q677488 | Number of tickers left: 42
# Trying to retrieve: Q319344
# Succeeded in retrieving: Q319344 | Number of tickers left: 41
# Trying to retrieve: Q784804
# Succeeded in retrieving: Q784804 | Number of tickers left: 40
# Trying to retrieve: Q2843129
# Succeeded in retrieving: Q2843129 | Number of tickers left: 39
# Trying to retrieve: Q470317
# Succeeded in retrieving: Q470317 | Number of tickers left: 38
# Trying to retrieve: Q787044
# Succeeded in retrieving: Q787044 | Number of tickers left: 37
# Trying to retrieve: Q822614
# Succeeded in retrieving: Q822614 | Number of tickers left: 36
# Trying to retrieve: Q21198484
# Succeeded in retrieving: Q21198484 | Number of tickers left: 35
# Trying to retrieve: Q127074
# Succeeded in retrieving: Q127074 | Number of tickers left: 34
# Trying to retrieve: Q4698062
# Succeeded in retrieving: Q4698062 | Number of tickers left: 33
# Trying to retrieve: Q4671583
# Succeeded in retrieving: Q4671583 | Number of tickers left: 32
# Trying to retrieve: Q293796
# Succeeded in retrieving: Q293796 | Number of tickers left: 31
# Trying to retrieve: Q4781544
# Succeeded in retrieving: Q4781544 | Number of tickers left: 30
# Trying to retrieve: Q4649932
# Succeeded in retrieving: Q4649932 | Number of tickers left: 29
# Trying to retrieve: Q212235
# Succeeded in retrieving: Q212235 | Number of tickers left: 28
# Trying to retrieve: Q5439999
# Succeeded in retrieving: Q5439999 | Number of tickers left: 27
# Trying to retrieve: Q292292
# Succeeded in retrieving: Q292292 | Number of tickers left: 26
# Trying to retrieve: Q26311
# Succeeded in retrieving: Q26311 | Number of tickers left: 25
# Trying to retrieve: Q4743779
# Succeeded in retrieving: Q4743779 | Number of tickers left: 24
# Trying to retrieve: Q26049
# Succeeded in retrieving: Q26049 | Number of tickers left: 23
# Trying to retrieve: Q291508
# Succeeded in retrieving: Q291508 | Number of tickers left: 22
# Trying to retrieve: Q4687934
# Succeeded in retrieving: Q4687934 | Number of tickers left: 21
# Trying to retrieve: Q464092
# Succeeded in retrieving: Q464092 | Number of tickers left: 20
# Trying to retrieve: Q2842931
# Succeeded in retrieving: Q2842931 | Number of tickers left: 19
# Trying to retrieve: Q462984
# Succeeded in retrieving: Q462984 | Number of tickers left: 18
# Trying to retrieve: Q4680345
# Succeeded in retrieving: Q4680345 | Number of tickers left: 17
# Trying to retrieve: Q632694
# Succeeded in retrieving: Q632694 | Number of tickers left: 16
# Trying to retrieve: Q338825
# Succeeded in retrieving: Q338825 | Number of tickers left: 15
# Trying to retrieve: Q2825507
# Succeeded in retrieving: Q2825507 | Number of tickers left: 14
# Trying to retrieve: Q447855
# Succeeded in retrieving: Q447855 | Number of tickers left: 13
# Trying to retrieve: Q288129
# Succeeded in retrieving: Q288129 | Number of tickers left: 12
# Trying to retrieve: Q4743275
# Succeeded in retrieving: Q4743275 | Number of tickers left: 11
# Trying to retrieve: Q808908
# Succeeded in retrieving: Q808908 | Number of tickers left: 10
# Trying to retrieve: Q306764
# Succeeded in retrieving: Q306764 | Number of tickers left: 9
# Trying to retrieve: Q4650338
# Succeeded in retrieving: Q4650338 | Number of tickers left: 8
# Trying to retrieve: Q4803735
# Succeeded in retrieving: Q4803735 | Number of tickers left: 7
# Trying to retrieve: Q470156
# Succeeded in retrieving: Q470156 | Number of tickers left: 6
# Trying to retrieve: Q14662364
# Succeeded in retrieving: Q14662364 | Number of tickers left: 5
# Trying to retrieve: Q52825
# Succeeded in retrieving: Q52825 | Number of tickers left: 4
# Trying to retrieve: Q4732268
# Succeeded in retrieving: Q4732268 | Number of tickers left: 3
# Trying to retrieve: Q4686051
# Succeeded in retrieving: Q4686051 | Number of tickers left: 2
# Trying to retrieve: Q10397787
# Succeeded in retrieving: Q10397787 | Number of tickers left: 1
# Trying to retrieve: Q393762
# Succeeded in retrieving: Q393762 | Number of tickers left: 0

# %%
failed_tickers
# Out:
# ['Q7447744', 'Q20656950', 'Q6030036', 'Q16976069', 'Q5332702', 'Q6394386']

# %%
all_company_triplets = pd.DataFrame(company_triplets)

# %%
latest_failed_tickers = pd.DataFrame(failed_tickers, columns=['ticker'])

# %%
latest_failed_tickers
# Out:
#       ticker
# 0   Q7447744
# 1  Q20656950
# 2   Q6030036
# 3  Q16976069
# 4   Q5332702
# 5   Q6394386

# %%
all_company_triplets.to_csv(data_dir/'full_company_relationships_triplets_Jun2021.csv', index=False)
all_company_triplets.to_hdf(data_dir/'full_company_relationships_triplets_Jun2021_keydata.h5', key='data')

# %%
latest_failed_tickers.to_csv(data_dir/'failed_tickers_Jun2021.csv', index=False)
